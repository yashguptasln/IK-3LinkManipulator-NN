# %% [markdown]
# <a href="https://colab.research.google.com/github/yashguptasln/IK-3LinkManipulator-NN/blob/new_Line/src/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import math
import csv
import random
from matplotlib import pyplot as plt

# %%
#its changing
# Lengths for three links of the Robotic Arm
LINK1 = 14.0
LINK2 = 22.0
LINK3 = 6.0

# No of rows/samples to generate for the dataset
SAMPLES = 1500

# Number of digits after decimal point to keep in the data points
PRECISION = 3

# Number of epochs to iterate while training the model
NUMBER_OF_EPOCHS = 100

ARROW_LENGTH = 0.7

# %% [markdown]
# <h3><u>Generating Dataset</u></h3>

# %% [markdown]
# - Creating the Helper Functions:

# %%
#Angles are in Radian
def getXCoordinate(AngQ1, AngQ2, AngQ3):
    return LINK1*math.cos(AngQ1) + LINK2*math.cos(AngQ1 + AngQ2) + LINK3*math.cos(AngQ1 + AngQ2 + AngQ3)

def getYCoordinate(AngQ1, AngQ2, AngQ3):
    return LINK1*math.sin(AngQ1) + LINK2*math.sin(AngQ1 + AngQ2) + LINK3*math.sin(AngQ1 + AngQ2 + AngQ3)

def getTotalAngle(AngQ1, AngQ2, AngQ3):
    return math.degrees(AngQ1 + AngQ2 + AngQ3)

# %%
def generateDataset():
    with open('training_data.csv', mode='w', newline='') as csv_file:
        writer = csv.DictWriter(csv_file, fieldnames = ["Q1", "Q2", "Q3", "XCoordEndEff", "YCoordEndEff", "TotalAngle"])
        writer.writeheader()

        for i in range (0,SAMPLES):
            #Randomly generating joint angles 
            q1= round(random.uniform(0, math.pi), PRECISION)
            q2= round(random.uniform(-math.pi, 0), PRECISION)
            q3= round(random.uniform(-math.pi/2, math.pi/2), PRECISION)

            writer.writerow({
                'Q1':q1,
                'Q2':q2,
                'Q3':q3,
                'XCoordEndEff':str(round(getXCoordinate(q1, q2, q3), PRECISION)),
                'YCoordEndEff':str(round(getYCoordinate(q1, q2, q3), PRECISION)),
                'TotalAngle':str(round(getTotalAngle(q1, q2, q3), PRECISION))
            })

# %% [markdown]
# - Generate Dataset:

# %%
#Uncomment the next line if to generate the dataset
#generateDataset()

# %%
dataset = pd.read_csv('training_data.csv')
dataset
# Out:
#          Q1     Q2     Q3  XCoordEndEff  YCoordEndEff  TotalAngle
# 0     0.571 -0.210 -0.947        37.360        12.019     -33.575
# 1     0.732 -2.482 -0.524         2.612       -16.867    -130.291
# 2     0.145 -2.527 -0.355        -7.615       -15.489    -156.819
# 3     2.325 -1.726  1.218         7.122        28.426     104.106
# 4     0.798 -2.590  1.145         9.734       -15.057     -37.070
# ...     ...    ...    ...           ...           ...         ...
# 1495  1.637 -2.494 -0.295        15.917        -8.142     -66.005
# 1496  1.298 -1.014  0.621        28.597        24.365      51.853
# 1497  1.594 -2.105 -1.440        16.638        -2.334    -111.784
# 1498  0.854 -0.158 -1.203        31.326        21.747     -29.049
# 1499  2.447 -3.117 -0.106        10.770        -8.903     -44.462
#
# [1500 rows x 6 columns]

# %%
coordX = dataset.iloc[:, [3]].values
coordY = dataset.iloc[:, [4]].values
thetaAng = dataset.iloc[:, [5]].values

# %%
#function to plot data points
def plotDataset():
    plt.figure(figsize=(9, 7))
    for i in range(len(coordX)):
        posx = coordX[i][0]
        posy = coordY[i][0]
        theta = thetaAng[i][0]
        plt.plot([posx, posx + ARROW_LENGTH * math.cos(math.radians(theta))], [posy, posy + ARROW_LENGTH * math.sin(math.radians(theta))],'k-')

    plt.scatter(coordX, coordY)
    plt.xlabel("X Axis")
    plt.ylabel("Y Axis")
    plt.title("Data set of " + str(SAMPLES) + " possible endeffector positions and orientations")
    dataset_fig = plt.gcf()
    plt.show()
    plt.draw()
    #dataset_fig.savefig('Plot of Data Points.png', dpi=100, bbox_inches='tight')

# %%
plotDataset()

# %%
# Removing duplicated end effector positions
dups = dataset.duplicated(subset=["XCoordEndEff", "YCoordEndEff"])

# duplicated() method returns a series which contain false for all the unique values/rows
# Since the deduplicated dataset must contain only unique values we invert "dups" and select 
# all the rows which are true in "dups" 
dataset = dataset[~dups]
dataset
# Out:
#          Q1     Q2     Q3  XCoordEndEff  YCoordEndEff  TotalAngle
# 0     0.571 -0.210 -0.947        37.360        12.019     -33.575
# 1     0.732 -2.482 -0.524         2.612       -16.867    -130.291
# 2     0.145 -2.527 -0.355        -7.615       -15.489    -156.819
# 3     2.325 -1.726  1.218         7.122        28.426     104.106
# 4     0.798 -2.590  1.145         9.734       -15.057     -37.070
# ...     ...    ...    ...           ...           ...         ...
# 1495  1.637 -2.494 -0.295        15.917        -8.142     -66.005
# 1496  1.298 -1.014  0.621        28.597        24.365      51.853
# 1497  1.594 -2.105 -1.440        16.638        -2.334    -111.784
# 1498  0.854 -0.158 -1.203        31.326        21.747     -29.049
# 1499  2.447 -3.117 -0.106        10.770        -8.903     -44.462
#
# [1500 rows x 6 columns]

# %%
#The X and Y Coordinates and the end effector orientation is the input to the model
X = dataset.iloc[:, 3:].values

#The joint angles are the output from the model
y = dataset.iloc[:, :3].values

# %%
#Splitting dataset into training and test data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, shuffle=1, random_state=0)

# %%
# Feature Scaling
# Feature Scaling is done to ease the calculations involved while training the model
# also avoid any independent variable dominating another one

# Using MinMaxScaler to scale all the values to [-1, 1] range

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(-1, 1))
X_train = scaler.fit_transform(X_train)
scaler = MinMaxScaler(feature_range=(-1, 1))
X_test = scaler.fit_transform(X_test)

# %%
# 70% - Training, 15% - Validation, 15% - Testing
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.18, random_state=0)#0.25

# %%
import tensorflow as tf
from tensorflow import keras

# %%
#Function to build the neural network model
def build_model():
    model = keras.Sequential()
    model.add(keras.layers.Dense(3, activation='linear', input_shape=(3, )))
    model.add(keras.layers.Dense(100, activation='relu'))
    model.add(keras.layers.Dense(3, activation='linear'))
    model.compile(optimizer=tf.keras.optimizers.Adam(0.05), loss=tf.losses.mean_squared_error, metrics=['accuracy'])
    return model

# %%
#Building the model
model = build_model()

# %%
#Training the model
history = model.fit(
    x=X_train, 
    y=y_train,
    epochs=NUMBER_OF_EPOCHS,
    verbose=2,
    validation_data=(X_val, y_val)
)
# Out:
# Epoch 1/100
# 33/33 - 0s - loss: 0.6533 - accuracy: 0.8756 - val_loss: 0.3265 - val_accuracy: 0.8783
# Epoch 2/100
# 33/33 - 0s - loss: 0.1994 - accuracy: 0.9110 - val_loss: 0.1199 - val_accuracy: 0.9391
# Epoch 3/100
# 33/33 - 0s - loss: 0.0842 - accuracy: 0.9234 - val_loss: 0.0870 - val_accuracy: 0.9217
# Epoch 4/100
# 33/33 - 0s - loss: 0.0827 - accuracy: 0.9206 - val_loss: 0.0897 - val_accuracy: 0.9435
# Epoch 5/100
# 33/33 - 0s - loss: 0.0754 - accuracy: 0.9254 - val_loss: 0.0686 - val_accuracy: 0.9565
# Epoch 6/100
# 33/33 - 0s - loss: 0.0607 - accuracy: 0.9407 - val_loss: 0.0715 - val_accuracy: 0.9304
# Epoch 7/100
# 33/33 - 0s - loss: 0.0753 - accuracy: 0.9301 - val_loss: 0.0637 - val_accuracy: 0.9522
# Epoch 8/100
# 33/33 - 0s - loss: 0.0645 - accuracy: 0.9493 - val_loss: 0.0668 - val_accuracy: 0.9391
# Epoch 9/100
# 33/33 - 0s - loss: 0.0543 - accuracy: 0.9397 - val_loss: 0.0551 - val_accuracy: 0.9652
# Epoch 10/100
# 33/33 - 0s - loss: 0.0542 - accuracy: 0.9407 - val_loss: 0.0748 - val_accuracy: 0.9304
# Epoch 11/100
# 33/33 - 0s - loss: 0.0567 - accuracy: 0.9407 - val_loss: 0.0604 - val_accuracy: 0.9435
# Epoch 12/100
# 33/33 - 0s - loss: 0.0656 - accuracy: 0.9340 - val_loss: 0.0583 - val_accuracy: 0.9522
# Epoch 13/100
# 33/33 - 0s - loss: 0.0552 - accuracy: 0.9359 - val_loss: 0.0456 - val_accuracy: 0.9609
# Epoch 14/100
# 33/33 - 0s - loss: 0.0570 - accuracy: 0.9407 - val_loss: 0.0599 - val_accuracy: 0.9565
# Epoch 15/100
# 33/33 - 0s - loss: 0.0594 - accuracy: 0.9445 - val_loss: 0.0630 - val_accuracy: 0.9391
# Epoch 16/100
# 33/33 - 0s - loss: 0.0617 - accuracy: 0.9407 - val_loss: 0.0575 - val_accuracy: 0.9609
# Epoch 17/100
# 33/33 - 0s - loss: 0.0563 - accuracy: 0.9388 - val_loss: 0.0601 - val_accuracy: 0.9261
# Epoch 18/100
# 33/33 - 0s - loss: 0.0481 - accuracy: 0.9455 - val_loss: 0.0773 - val_accuracy: 0.9478
# Epoch 19/100
# 33/33 - 0s - loss: 0.0511 - accuracy: 0.9455 - val_loss: 0.0559 - val_accuracy: 0.9522
# Epoch 20/100
# 33/33 - 0s - loss: 0.0611 - accuracy: 0.9215 - val_loss: 0.0635 - val_accuracy: 0.9435
# Epoch 21/100
# 33/33 - 0s - loss: 0.0442 - accuracy: 0.9388 - val_loss: 0.0374 - val_accuracy: 0.9391
# Epoch 22/100
# 33/33 - 0s - loss: 0.0382 - accuracy: 0.9502 - val_loss: 0.0606 - val_accuracy: 0.9435
# Epoch 23/100
# 33/33 - 0s - loss: 0.0423 - accuracy: 0.9502 - val_loss: 0.0341 - val_accuracy: 0.9522
# Epoch 24/100
# 33/33 - 0s - loss: 0.0440 - accuracy: 0.9493 - val_loss: 0.0537 - val_accuracy: 0.9522
# Epoch 25/100
# 33/33 - 0s - loss: 0.0407 - accuracy: 0.9483 - val_loss: 0.0431 - val_accuracy: 0.9391
# Epoch 26/100
# 33/33 - 0s - loss: 0.0405 - accuracy: 0.9550 - val_loss: 0.0535 - val_accuracy: 0.9609
# Epoch 27/100
# 33/33 - 0s - loss: 0.0410 - accuracy: 0.9569 - val_loss: 0.0351 - val_accuracy: 0.9478
# Epoch 28/100
# 33/33 - 0s - loss: 0.0291 - accuracy: 0.9598 - val_loss: 0.0261 - val_accuracy: 0.9783
# Epoch 29/100
# 33/33 - 0s - loss: 0.0287 - accuracy: 0.9646 - val_loss: 0.0397 - val_accuracy: 0.9565
# Epoch 30/100
# 33/33 - 0s - loss: 0.0437 - accuracy: 0.9426 - val_loss: 0.0398 - val_accuracy: 0.9696
# Epoch 31/100
# 33/33 - 0s - loss: 0.0375 - accuracy: 0.9512 - val_loss: 0.0517 - val_accuracy: 0.9435
# Epoch 32/100
# 33/33 - 0s - loss: 0.0315 - accuracy: 0.9617 - val_loss: 0.0746 - val_accuracy: 0.9739
# Epoch 33/100
# 33/33 - 0s - loss: 0.0434 - accuracy: 0.9608 - val_loss: 0.0542 - val_accuracy: 0.9478
# Epoch 34/100
# 33/33 - 0s - loss: 0.0393 - accuracy: 0.9483 - val_loss: 0.0245 - val_accuracy: 0.9609
# Epoch 35/100
# 33/33 - 0s - loss: 0.0314 - accuracy: 0.9579 - val_loss: 0.0547 - val_accuracy: 0.9522
# Epoch 36/100
# 33/33 - 0s - loss: 0.0474 - accuracy: 0.9522 - val_loss: 0.0465 - val_accuracy: 0.9478
# Epoch 37/100
# 33/33 - 0s - loss: 0.0591 - accuracy: 0.9455 - val_loss: 0.0708 - val_accuracy: 0.9435
# Epoch 38/100
# 33/33 - 0s - loss: 0.0494 - accuracy: 0.9541 - val_loss: 0.0400 - val_accuracy: 0.9348
# Epoch 39/100
# 33/33 - 0s - loss: 0.0570 - accuracy: 0.9397 - val_loss: 0.0527 - val_accuracy: 0.9565
# Epoch 40/100
# 33/33 - 0s - loss: 0.0385 - accuracy: 0.9531 - val_loss: 0.0387 - val_accuracy: 0.9609
# Epoch 41/100
# 33/33 - 0s - loss: 0.0390 - accuracy: 0.9569 - val_loss: 0.0268 - val_accuracy: 0.9652
# Epoch 42/100
# 33/33 - 0s - loss: 0.0357 - accuracy: 0.9541 - val_loss: 0.0307 - val_accuracy: 0.9696
# Epoch 43/100
# 33/33 - 0s - loss: 0.0295 - accuracy: 0.9627 - val_loss: 0.0318 - val_accuracy: 0.9739
# Epoch 44/100
# 33/33 - 0s - loss: 0.0264 - accuracy: 0.9684 - val_loss: 0.0289 - val_accuracy: 0.9783
# Epoch 45/100
# 33/33 - 0s - loss: 0.0391 - accuracy: 0.9512 - val_loss: 0.0293 - val_accuracy: 0.9652
# Epoch 46/100
# 33/33 - 0s - loss: 0.0435 - accuracy: 0.9550 - val_loss: 0.0382 - val_accuracy: 0.9826
# Epoch 47/100
# 33/33 - 0s - loss: 0.0415 - accuracy: 0.9608 - val_loss: 0.0420 - val_accuracy: 0.9652
# Epoch 48/100
# 33/33 - 0s - loss: 0.0411 - accuracy: 0.9435 - val_loss: 0.0566 - val_accuracy: 0.9783
# Epoch 49/100
# 33/33 - 0s - loss: 0.0383 - accuracy: 0.9560 - val_loss: 0.0441 - val_accuracy: 0.9435
# Epoch 50/100
# 33/33 - 0s - loss: 0.0309 - accuracy: 0.9684 - val_loss: 0.0386 - val_accuracy: 0.9870
# Epoch 51/100
# 33/33 - 0s - loss: 0.0379 - accuracy: 0.9713 - val_loss: 0.0400 - val_accuracy: 0.9739
# Epoch 52/100
# 33/33 - 0s - loss: 0.0328 - accuracy: 0.9569 - val_loss: 0.0327 - val_accuracy: 0.9522
# Epoch 53/100
# 33/33 - 0s - loss: 0.0399 - accuracy: 0.9550 - val_loss: 0.0497 - val_accuracy: 0.9739
# Epoch 54/100
# 33/33 - 0s - loss: 0.0464 - accuracy: 0.9340 - val_loss: 0.0329 - val_accuracy: 0.9565
# Epoch 55/100
# 33/33 - 0s - loss: 0.0347 - accuracy: 0.9550 - val_loss: 0.0318 - val_accuracy: 0.9652
# Epoch 56/100
# 33/33 - 0s - loss: 0.0269 - accuracy: 0.9589 - val_loss: 0.0252 - val_accuracy: 0.9783
# Epoch 57/100
# 33/33 - 0s - loss: 0.0260 - accuracy: 0.9684 - val_loss: 0.0224 - val_accuracy: 0.9435
# Epoch 58/100
# 33/33 - 0s - loss: 0.0338 - accuracy: 0.9598 - val_loss: 0.0280 - val_accuracy: 0.9609
# Epoch 59/100
# 33/33 - 0s - loss: 0.0279 - accuracy: 0.9589 - val_loss: 0.0442 - val_accuracy: 0.9435
# Epoch 60/100
# 33/33 - 0s - loss: 0.0390 - accuracy: 0.9589 - val_loss: 0.0368 - val_accuracy: 0.9435
# Epoch 61/100
# 33/33 - 0s - loss: 0.0289 - accuracy: 0.9665 - val_loss: 0.0248 - val_accuracy: 0.9739
# Epoch 62/100
# 33/33 - 0s - loss: 0.0262 - accuracy: 0.9694 - val_loss: 0.0332 - val_accuracy: 0.9652
# Epoch 63/100
# 33/33 - 0s - loss: 0.0320 - accuracy: 0.9512 - val_loss: 0.0346 - val_accuracy: 0.9826
# Epoch 64/100
# 33/33 - 0s - loss: 0.0371 - accuracy: 0.9550 - val_loss: 0.0307 - val_accuracy: 0.9609
# Epoch 65/100
# 33/33 - 0s - loss: 0.0409 - accuracy: 0.9502 - val_loss: 0.0372 - val_accuracy: 0.9391
# Epoch 66/100
# 33/33 - 0s - loss: 0.0360 - accuracy: 0.9560 - val_loss: 0.0333 - val_accuracy: 0.9522
# Epoch 67/100
# 33/33 - 0s - loss: 0.0433 - accuracy: 0.9502 - val_loss: 0.0319 - val_accuracy: 0.9696
# Epoch 68/100
# 33/33 - 0s - loss: 0.0331 - accuracy: 0.9569 - val_loss: 0.0341 - val_accuracy: 0.9435
# Epoch 69/100
# 33/33 - 0s - loss: 0.0470 - accuracy: 0.9426 - val_loss: 0.0517 - val_accuracy: 0.9130
# Epoch 70/100
# 33/33 - 0s - loss: 0.0374 - accuracy: 0.9550 - val_loss: 0.0456 - val_accuracy: 0.9652
# Epoch 71/100
# 33/33 - 0s - loss: 0.0311 - accuracy: 0.9646 - val_loss: 0.0264 - val_accuracy: 0.9522
# Epoch 72/100
# 33/33 - 0s - loss: 0.0264 - accuracy: 0.9550 - val_loss: 0.0315 - val_accuracy: 0.9739
# Epoch 73/100
# 33/33 - 0s - loss: 0.0306 - accuracy: 0.9694 - val_loss: 0.0442 - val_accuracy: 0.9739
# Epoch 74/100
# 33/33 - 0s - loss: 0.0303 - accuracy: 0.9636 - val_loss: 0.0317 - val_accuracy: 0.9435
# Epoch 75/100
# 33/33 - 0s - loss: 0.0401 - accuracy: 0.9541 - val_loss: 0.0442 - val_accuracy: 0.9217
# Epoch 76/100
# 33/33 - 0s - loss: 0.0300 - accuracy: 0.9598 - val_loss: 0.0289 - val_accuracy: 0.9826
# Epoch 77/100
# 33/33 - 0s - loss: 0.0252 - accuracy: 0.9636 - val_loss: 0.0289 - val_accuracy: 0.9565
# Epoch 78/100
# 33/33 - 0s - loss: 0.0320 - accuracy: 0.9579 - val_loss: 0.0229 - val_accuracy: 0.9826
# Epoch 79/100
# 33/33 - 0s - loss: 0.0273 - accuracy: 0.9703 - val_loss: 0.0279 - val_accuracy: 0.9609
# Epoch 80/100
# 33/33 - 0s - loss: 0.0425 - accuracy: 0.9541 - val_loss: 0.0593 - val_accuracy: 0.9348
# Epoch 81/100
# 33/33 - 0s - loss: 0.0423 - accuracy: 0.9589 - val_loss: 0.0317 - val_accuracy: 0.9870
# Epoch 82/100
# 33/33 - 0s - loss: 0.0333 - accuracy: 0.9608 - val_loss: 0.0349 - val_accuracy: 0.9522
# Epoch 83/100
# 33/33 - 0s - loss: 0.0235 - accuracy: 0.9646 - val_loss: 0.0257 - val_accuracy: 0.9522
# Epoch 84/100
# 33/33 - 0s - loss: 0.0249 - accuracy: 0.9550 - val_loss: 0.0281 - val_accuracy: 0.9652
# Epoch 85/100
# 33/33 - 0s - loss: 0.0339 - accuracy: 0.9560 - val_loss: 0.0504 - val_accuracy: 0.9348
# Epoch 86/100
# 33/33 - 0s - loss: 0.0474 - accuracy: 0.9445 - val_loss: 0.0558 - val_accuracy: 0.9478
# Epoch 87/100
# 33/33 - 0s - loss: 0.0428 - accuracy: 0.9560 - val_loss: 0.0434 - val_accuracy: 0.9652
# Epoch 88/100
# 33/33 - 0s - loss: 0.0353 - accuracy: 0.9579 - val_loss: 0.0303 - val_accuracy: 0.9696
# Epoch 89/100
# 33/33 - 0s - loss: 0.0331 - accuracy: 0.9646 - val_loss: 0.0312 - val_accuracy: 0.9783
# Epoch 90/100
# 33/33 - 0s - loss: 0.0306 - accuracy: 0.9522 - val_loss: 0.0248 - val_accuracy: 0.9696
# Epoch 91/100
# 33/33 - 0s - loss: 0.0352 - accuracy: 0.9579 - val_loss: 0.0242 - val_accuracy: 0.9565
# Epoch 92/100
# 33/33 - 0s - loss: 0.0269 - accuracy: 0.9617 - val_loss: 0.0258 - val_accuracy: 0.9783
# Epoch 93/100
# 33/33 - 0s - loss: 0.0336 - accuracy: 0.9636 - val_loss: 0.0251 - val_accuracy: 0.9696
# Epoch 94/100
# 33/33 - 0s - loss: 0.0241 - accuracy: 0.9627 - val_loss: 0.0262 - val_accuracy: 0.9696
# Epoch 95/100
# 33/33 - 0s - loss: 0.0330 - accuracy: 0.9569 - val_loss: 0.0207 - val_accuracy: 0.9826
# Epoch 96/100
# 33/33 - 0s - loss: 0.0393 - accuracy: 0.9646 - val_loss: 0.0420 - val_accuracy: 0.9522
# Epoch 97/100
# 33/33 - 0s - loss: 0.0361 - accuracy: 0.9541 - val_loss: 0.0413 - val_accuracy: 0.9565
# Epoch 98/100
# 33/33 - 0s - loss: 0.0552 - accuracy: 0.9330 - val_loss: 0.0529 - val_accuracy: 0.9217
# Epoch 99/100
# 33/33 - 0s - loss: 0.0437 - accuracy: 0.9378 - val_loss: 0.0524 - val_accuracy: 0.9565
# Epoch 100/100
# 33/33 - 0s - loss: 0.0316 - accuracy: 0.9608 - val_loss: 0.0317 - val_accuracy: 0.9652

# %%
#Evaluating model on testing data 
print('Testing the model:\n')

test_loss, test_acc = model.evaluate(X_test, y_test)

print('\nTesting Loss = ', test_loss) 
print('Testing Accuracy = ', test_acc)
# Out:
# Testing the model:
#
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0245 - accuracy: 0.9733
#
# Testing Loss =  0.024466391652822495
# Testing Accuracy =  0.9733333587646484

# %%
#print(history.history.keys())

# %%
# Summarize history for accuracy

plt.figure(figsize=(15, 10))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.xticks(np.arange(0, NUMBER_OF_EPOCHS+1, 10))

model_acc_fig = plt.gcf()
plt.show()
plt.draw()
#model_acc_fig.savefig('Model Accuracy.png', dpi=100, bbox_inches='tight')

# %%
# Summarize history for loss

plt.figure(figsize=(15, 10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss (Mean Squared Error)')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.xticks(np.arange(0, NUMBER_OF_EPOCHS+1, 10))
model_loss_fig = plt.gcf()
plt.show()
plt.draw()
#model_loss_fig.savefig('Model Loss(MSE).png', dpi=100, bbox_inches='tight')

# %%
X_test.shape
# Out:
# (225, 3)

# %%
# Make Predictions
predictions = model.predict(X_test)

# %%
# Scatter Plot for True Value vs Predictions of Joint Angles
plt.figure(figsize=(9, 9))
plt.scatter(y_test[:, 0], predictions[:, 0], label="Joint Angle 1 (Q1)", c="red",alpha=0.5)
plt.scatter(y_test[:, 1], predictions[:, 1], label="Joint Angle 2 (Q2)", c="blue",alpha=0.5)
plt.scatter(y_test[:, 2], predictions[:, 2], label="Joint Angle 3 (Q3)", c="green",alpha=0.5)

plt.title("True Value vs Predictions")
plt.xlabel('True Value of angle (rad)')
plt.ylabel('Predictions of angle (rad)')
plt.legend(loc='upper left')
actual_prediction_fig = plt.gcf()
plt.show()
plt.draw()
#actual_prediction_fig.savefig('True Value Vs Prediction.png', dpi=100, bbox_inches='tight')

# %%
# Get Predicted Coordinates

# We need to derive the predicted coordinates from the predicted joint angles.
predicted_coord = np.empty((len(predictions), 3))
for i in range(len(predictions)):
    ang = predictions[i, :]
    predicted_coord[i, 0] = getXCoordinate(ang[0], ang[1], ang[2])
    predicted_coord[i, 1] = getYCoordinate(ang[0], ang[1], ang[2])
    predicted_coord[i, 2] = getTotalAngle(ang[0], ang[1], ang[2])

# %%
# Getting the Actual Coordinates

# We need to inverse transform to get the coordinates back to the original range
# as they we transformed to range [-1, 1] during feature scaling.
actual_coord = scaler.inverse_transform(X_test)

# %%
# Plotting the Actual Position and the Predicted position of the end effector
plt.figure(figsize=(9, 7))
plt.scatter(actual_coord[:, 0], actual_coord[:, 1], label="Actual Value", c="blue",alpha=0.5)
plt.scatter(predicted_coord[:, 0], predicted_coord[:, 1], label="Predicted Value", c="green",alpha=0.5)

for i in range(len(actual_coord)):
        posx = actual_coord[i][0]
        posy = actual_coord[i][1]
        theta = actual_coord[i][2]
        plt.plot([posx, posx + ARROW_LENGTH * math.cos(math.radians(theta))], [posy, posy + ARROW_LENGTH * math.sin(math.radians(theta))],'k-')
        
        posx = predicted_coord[i][0]
        posy = predicted_coord[i][1]
        theta = predicted_coord[i][2]
        plt.plot([posx, posx + ARROW_LENGTH * math.cos(math.radians(theta))], [posy, posy + ARROW_LENGTH * math.sin(math.radians(theta))],'k-')

plt.legend(loc='upper left')
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("Actual Position and the Predicted position of the end effector")
actual_predicted_fig = plt.gcf()
plt.show()
plt.draw()
#actual_predicted_fig.savefig('Plot of Actual Position and the Predicted position.png', dpi=100, bbox_inches='tight')
